# %% [markdown]
# # Random Over-sampling
#
# Random over-sampling consists in extracting at random samples from the minority class, until they reach a certain proportion compared to the majority class, typically 50:50, or in other words, a balancing ratio of 1.
#
# In Random over-sampling, we extract samples from the minority class at random, with replacement.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# ## Create data
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# We will create 2 classes, one majority one minority, clearly separated to facilitate the demonstration.

# %%
# Configuration options
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Generate X
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# transform arrays to pandas formats
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# create an imbalancced Xset
# (make blobs creates same number of obs per class
# we need to downsample manually)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# display size
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X.head()
# Out:
#         VarA      VarB
# 3  -0.506815 -2.404280
# 4  -0.240962 -1.284420
# 5   0.507779 -4.066927
# 6   0.575826  1.346243
# 10 -2.492690 -0.696048

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## Random Over-sampling
#
# [RandomOverSampler](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.RandomOverSampler.html)
#
#
# Selects samples from the minority class at random, with replacement, until we have as many observations as those in the majority class (or any other balancing ratio we wish).

# %%
ros = RandomOverSampler(
    sampling_strategy='auto', # samples only the minority class
    random_state=0,  # for reproducibility
)  

X_res, y_res = ros.fit_resample(X, y)

# %%
# size of original data

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# size of undersampled data

X_res.shape, y_res.shape
# Out:
# ((1600, 2), (1600,))

# %%
# number of minority class observations

y.value_counts(), y_res.value_counts()
# Out:
# (0    800
#  1    200
#  dtype: int64, 0    800
#  1    800
#  dtype: int64)

# %%
# plot of original data

sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# plot of resampled data

sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('Over-sampled dataset')
plt.show()

# %% [markdown]
# The reason why we do not see as if there were more observations from the minority, is because they are identical to the other ones, so they are plotted on top. We notice there are more, because the orange colour is darker.

# %% [markdown]
# # SMOTE
#
# Creates new samples by interpolation of samples of the minority class and any of its k nearest neighbours (also from the minority class). K is typically 5.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## Create data
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# We will create 2 classes, one majority one minority, clearly separated to facilitate the demonstration.

# %%
# Configuration options
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Generate X
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# transform arrays to pandas formats
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# create an imbalancced Xset
# (make blobs creates same number of obs per class
# we need to downsample manually)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# display size
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## SMOTE
#
# [SMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html)

# %%
sm = SMOTE(
    sampling_strategy='auto',  # samples only the minority class
    random_state=0,  # for reproducibility
    k_neighbors=5,
    n_jobs=4
)

X_res, y_res = sm.fit_resample(X, y)

# %%
# size of original data

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# size of undersampled data

X_res.shape, y_res.shape
# Out:
# ((1600, 2), (1600,))

# %%
# number of minority class observations

y.value_counts(), y_res.value_counts()
# Out:
# (0    800
#  1    200
#  dtype: int64, 0    800
#  1    800
#  dtype: int64)

# %%
# plot of original data

sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# plot of original data

sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('Over-sampled dataset')
plt.show()

# %% [markdown]
# There are now new observations that differ from the original ones.

# %% [markdown]
# # Random Undersampling
#
# Random undersampling consists in extracting at random samples from the majority class, until they reach a certain proportion compared to the minority class, typically 50:50.
#
# - **Criteria for data exclusion**: Random
# - **Final Dataset size**: 2 x minority class

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# ## Create data
#
# We will create data where the classes have different degrees of separateness.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html

# %%
def make_data(sep):
    
    # returns arrays
    X, y = make_classification(n_samples=1000,
                           n_features=2,
                           n_redundant=0,
                           n_clusters_per_class=1,
                           weights=[0.99],
                           class_sep=sep,# how separate the classes are
                           random_state=1)
    
    # trasform arrays into pandas df and series
    X = pd.DataFrame(X, columns =['varA', 'varB'])
    y = pd.Series(y)
    
    return X, y

# %%
# make datasets with different class separateness
# and plot

for sep in [0, 1, 2]:
    
    X, y = make_data(sep)
    
    print(y.value_counts())
    
    sns.scatterplot(
        data=X, x="varA", y="varB", hue=y
    )
    
    plt.title('Separation: {}'.format(sep))
    plt.show()
# Out:
# 0    983
# 1     17
# dtype: int64
# 0    983
# 1     17
# dtype: int64
# 0    983
# 1     17
# dtype: int64

# %% [markdown]
# As we increase the parameter **sep**, the minority and majority class show less degree of overlap.

# %% [markdown]
# ## Random Undersampling
#
# [RandomUnderSampler](https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.RandomUnderSampler.html)
#
# Selects samples from the majority class at random, until we have as many observations as those in the minority class.

# %%
# create data

X, y = make_data(sep=2)

# set up the random undersampling class

rus = RandomUnderSampler(
    sampling_strategy='auto',  # samples only the majority class
    random_state=0,  # for reproducibility
    replacement=True # if it should resample with replacement
)  

X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
# size of original data

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# size of undersampled data

X_resampled.shape, y_resampled.shape
# Out:
# ((34, 2), (34,))

# %%
# number of minority class observations

y.value_counts()
# Out:
# 0    983
# 1     17
# dtype: int64

# %%
# plot of original data

sns.scatterplot(
    data=X, x="varA", y="varB", hue=y
)

plt.title('Original dataset')
plt.show()

# %%
# plot undersampled data

sns.scatterplot(
    data=X_resampled, x="varA", y="varB", hue=y_resampled
)

plt.title('Undersampled dataset')
plt.show()

# %% [markdown]
# The samples show a similar observation as they do in the original dataset. This is the product of removing data at random.
#
#
# ## Changing the balancing ratio

# %%
# now, I will resample the data, so that I obtain
# twice as many observations from the majority as
# those from the minority

rus = RandomUnderSampler(
    sampling_strategy= 0.5,  # remember balancing ratio = x min / x maj
    random_state=0,  
    replacement=False # if it should resample with replacement
)  

X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
# size of undersampled data

X_resampled.shape, y_resampled.shape
# Out:
# ((51, 2), (51,))

# %%
# see that we have twice as many of the majority now

y_resampled.value_counts()
# Out:
# 0    34
# 1    17
# dtype: int64

# %%
# and we can also specify how many observations we want
# from each class

rus = RandomUnderSampler(
    sampling_strategy= {0:100, 1:15},  # remember balancing ratio = x min / x maj
    random_state=0,  
    replacement=False # if it should resample with replacement
)  

X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
# size of undersampled data

X_resampled.shape, y_resampled.shape
# Out:
# ((115, 2), (115,))

# %%
# we have what we asked for :)

y_resampled.value_counts()
# Out:
# 0    100
# 1     15
# dtype: int64

# %% [markdown]
# # Tomek Links
#
#
# Tomek links are 2 samples from a different class, which are nearest neighbours to each other. In other words, if 2 observations are nearest neighbours, and from a different class, they are Tomek Links.
#
# This procedures removes either the sample from the majority class if it is a Tomek Link, or alternatively, both observations, the one from the majority and the one from the minority class.
#
# ====
#
# - **Criteria for data exclusion**: Samples are Tomek Links
# - **Final Dataset size**: varies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from imblearn.under_sampling import TomekLinks

# %% [markdown]
# ## Create data
#
# We will create data where the classes have different degrees of separateness.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html

# %%
def make_data(sep):
    
    # returns arrays
    X, y = make_classification(n_samples=1000,
                           n_features=2,
                           n_redundant=0,
                           n_clusters_per_class=1,
                           weights=[0.99],
                           class_sep=sep,# how separate the classes are
                           random_state=1)
    
    # trasform arrays into pandas df and series
    X = pd.DataFrame(X, columns =['varA', 'varB'])
    y = pd.Series(y)
    
    return X, y

# %% [markdown]
# ## Undersample with Tomek Links
#
# [TomekLinks](https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.TomekLinks.html)
#
# ### Well separated classes

# %%
# create data

X, y = make_data(sep=2)

# set up Tomek Links

tl = TomekLinks(
    sampling_strategy='auto',  # undersamples only the majority class
    n_jobs=4)  # I have 4 cores in my laptop

X_resampled, y_resampled = tl.fit_resample(X, y)

# %%
# size of original data

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# size of undersampled data

X_resampled.shape, y_resampled.shape
# Out:
# ((994, 2), (994,))

# %%
# number of minority class observations

y.value_counts()
# Out:
# 0    983
# 1     17
# dtype: int64

# %%
sns.scatterplot(
    data=X, x="varA", y="varB", hue=y
)

plt.title('Original dataset')
plt.show()

# %%
# plot undersampled data

sns.scatterplot(
    data=X_resampled, x="varA", y="varB", hue=y_resampled
)

plt.title('Undersampled dataset')
plt.show()

# %% [markdown]
# ### Partially separated classes

# %%
# create data
X, y = make_data(sep=0.5)

# set up Tomek Links

tl = TomekLinks(
    sampling_strategy='auto',  # undersamples only the majority class
    n_jobs=4)  # I have 4 cores in my laptop

X_resampled, y_resampled = tl.fit_resample(X, y)

# %%
# original data

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# undersampled data

X_resampled.shape, y_resampled.shape
# Out:
# ((988, 2), (988,))

# %% [markdown]
# Note that more samples were excluded in the final training set, compared to the previous case where classes were more separated. This is because there are more Tomek Links, as the classes are now not so separated.

# %%
sns.scatterplot(
    data=X, x="varA", y="varB", hue=y
)

plt.title('Original dataset')
plt.show()

# %%
# plot undersampled data

sns.scatterplot(
    data=X_resampled, x="varA", y="varB", hue=y_resampled
)

plt.title('Undersampled dataset')
plt.show()

# %% [markdown]
# ## Ensemble Learning
#
# In this notebook, we will compare the performance of:
#
# - just re-sampling
# - just boosting or bagging
# - bagging + resamppling
# - boosting + resampling
# - bagging + boosting + resampling
#
# Utilizing classes from sklearn and imbalanced learn, over various datasets.

# %%
from collections import Counter

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import (
    RandomForestClassifier,
    BaggingClassifier,
    AdaBoostClassifier,
)

from sklearn.linear_model  import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from imblearn.datasets import fetch_datasets

from imblearn.under_sampling import RandomUnderSampler

from imblearn.over_sampling import SMOTE

from imblearn.ensemble import (
    BalancedBaggingClassifier,
    BalancedRandomForestClassifier,
    RUSBoostClassifier,
    EasyEnsembleClassifier,
)

# %%
! pip install imbalanced-learn==0.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imbalanced-learn==0.10.1
#   Downloading imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 KB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.10.1) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.10.1) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.10.1) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.10.1) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.10.1) (1.10.1)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.0
#     Uninstalling imbalanced-learn-0.10.0:
#       Successfully uninstalled imbalanced-learn-0.10.0
# Successfully installed imbalanced-learn-0.10.1

# %%
# just re-sampling methods (no classifier)

resampling_dict = {
    
    'random': RandomUnderSampler(
        sampling_strategy='auto',
        random_state=0
    ),

    'smote': SMOTE(
        sampling_strategy='auto',
        random_state=0,
        k_neighbors=5,
        n_jobs=4,
    ),
}

# %%
# ensemble methods (with or without resampling)

ensemble_dict = {

    # balanced random forests (bagging)
    'balancedRF': BalancedRandomForestClassifier(
        n_estimators=20,
        criterion='gini',
        max_depth=3,
        sampling_strategy='auto',
        n_jobs=4,
        random_state=2909,
    ),

    # bagging of Logistic regression, no resampling
    'bagging': BaggingClassifier(
        base_estimator=LogisticRegression(random_state=2909),
        n_estimators=20,
        n_jobs=4,
        random_state=2909,
    ),

    # bagging of Logistic regression, with resampling
    'balancedbagging': BalancedBaggingClassifier(
        base_estimator=LogisticRegression(random_state=2909),
        n_estimators=20,
        max_samples=1.0,  # The number of samples to draw from X to train each base estimator
        max_features=1.0,  # The number of features to draw from X to train each base estimator
        bootstrap=True,
        bootstrap_features=False,
        sampling_strategy='auto',
        n_jobs=4,
        random_state=2909,
    ),


    # bagging + boosting + under-sammpling
    'easyEnsemble': EasyEnsembleClassifier(
        n_estimators=20,
        sampling_strategy='auto',
        n_jobs=4,
        random_state=2909,
    ),
}

# %%
datasets_ls = [
    'thyroid_sick',
    'arrhythmia',
    'ozone_level'
]

# %%
# function to train random forests and evaluate the performance

def run_randomForests(X_train, X_test, y_train, y_test):

    rf = RandomForestClassifier(
        n_estimators=20, random_state=39, max_depth=2, n_jobs=4)
    rf.fit(X_train, y_train)

    print('Train set')
    pred = rf.predict_proba(X_train)
    print(
        'Random Forests roc-auc: {}'.format(roc_auc_score(y_train, pred[:, 1])))
    pred = rf.predict(X_train)
    print(
        'Random Forests metrics: ',(classification_report(y_train, pred)))

    print('Test set')
    pred = rf.predict_proba(X_test)
    print(
        'Random Forests roc-auc: {}'.format(roc_auc_score(y_test, pred[:, 1])))
    
    pred_ = rf.predict(X_test)
    print(
        'Random Forests metrics: ',(classification_report(y_test, pred_)))

    return roc_auc_score(y_test, pred[:, 1])

# %%
# function to train random forests and evaluate the peadaormance

def run_adaboost(X_train, X_test, y_train, y_test):

    ada = AdaBoostClassifier(n_estimators=20, random_state=2909)
    
    ada.fit(X_train, y_train)

    print('Train set')
    pred = ada.predict_proba(X_train)
    print(
        'AdaBoost roc-auc: {}'.format(roc_auc_score(y_train, pred[:, 1])))
    
    pred = ada.predict(X_train)
    print(
        'AdaBoost metrics: ', (classification_report(y_train, pred)))    

    print('Test set')
    pred = ada.predict_proba(X_test)
    print(
        'AdaBoost roc-auc: {}'.format(roc_auc_score(y_test, pred[:, 1])))
    pred_ = ada.predict(X_test)
    print(
        'AdaBoost metrics: ',(classification_report(y_test, pred_)))    


    return roc_auc_score(y_test, pred[:, 1])

# %%
# function to train random forests and evaluate the peensembleormance

def run_ensemble(ensemble, X_train, X_test, y_train, y_test):
    
    ensemble.fit(X_train, y_train)

    print('Train set')
    pred = ensemble.predict_proba(X_train)
    print(
        'ensembleBoost roc-auc: {}'.format(roc_auc_score(y_train, pred[:, 1])))
    
    pred = ensemble.predict(X_train)
    print(
        'ensembleBoost metrics: ', (classification_report(y_train, pred)))    


    print('Test set')
    pred = ensemble.predict_proba(X_test)
    print(
        'ensembleBoost roc-auc: {}'.format(roc_auc_score(y_test, pred[:, 1])))
    
    pred_ = ensemble.predict(X_test)
    print(
        'ensembleBoost metrics:' ,(classification_report(y_test, pred_)))    


    return roc_auc_score(y_test, pred[:, 1])

# %%
# to save the results
results_dict = {}

for dataset in datasets_ls:
    
    results_dict[dataset] = {}    
    print(dataset)
    
    # load dataset
    data = fetch_datasets()[dataset]
    
    # separate train and test
    X_train, X_test, y_train, y_test = train_test_split(
    data.data,  
    data.target, 
    test_size=0.3,
    random_state=0)
    
    # we set variables in the same scale
    scaler = MinMaxScaler().fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    # train model and store result
    roc = run_randomForests(X_train, X_test, y_train, y_test)
    results_dict[dataset]['full_data'] = roc
    print()
    
    # train model and store result
    roc = run_adaboost(X_train, X_test, y_train, y_test)
    results_dict[dataset]['full_data_adaboost'] = roc
    print()
    
    for sampler in resampling_dict.keys():
        
        print(sampler)
        
        # resample
        X_resampled, y_resampled = resampling_dict[sampler].fit_resample(X_train, y_train)
        
        # train model and store result
        roc = run_randomForests(X_resampled, X_test, y_resampled, y_test)
        results_dict[dataset][sampler] = roc
        print()
    
    for ensemble in ensemble_dict.keys():
        
        print(ensemble)
        
        # train model and store result
        roc = run_ensemble(ensemble_dict[ensemble], X_train, X_test, y_train, y_test)
        results_dict[dataset][ensemble] = roc
        print()
# Out:
# thyroid_sick
# Train set
# Random Forests roc-auc: 0.9659770036881864
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97      2486
#            1       0.00      0.00      0.00       154
#
#     accuracy                           0.94      2640
#    macro avg       0.47      0.50      0.48      2640
# weighted avg       0.89      0.94      0.91      2640
#
# Test set
# Random Forests roc-auc: 0.9488890256662768
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96      1055
#            1       0.00      0.00      0.00        77
#
#     accuracy                           0.93      1132
#    macro avg       0.47      0.50      0.48      1132
# weighted avg       0.87      0.93      0.90      1132
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Train set
# AdaBoost roc-auc: 0.9909388680506942
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.98      0.99      0.98      2486
#            1       0.82      0.64      0.72       154
#
#     accuracy                           0.97      2640
#    macro avg       0.90      0.82      0.85      2640
# weighted avg       0.97      0.97      0.97      2640
#
# Test set
# AdaBoost roc-auc: 0.9634086292854065
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.98      0.99      0.98      1055
#            1       0.83      0.74      0.78        77
#
#     accuracy                           0.97      1132
#    macro avg       0.90      0.86      0.88      1132
# weighted avg       0.97      0.97      0.97      1132
#
#
# random
# Train set
# Random Forests roc-auc: 0.9752698600101198
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.92      0.99      0.95       154
#            1       0.99      0.92      0.95       154
#
#     accuracy                           0.95       308
#    macro avg       0.95      0.95      0.95       308
# weighted avg       0.95      0.95      0.95       308
#
# Test set
# Random Forests roc-auc: 0.9449252169631316
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.93      0.96      1055
#            1       0.46      0.87      0.60        77
#
#     accuracy                           0.92      1132
#    macro avg       0.73      0.90      0.78      1132
# weighted avg       0.95      0.92      0.93      1132
#
#
# smote
# /usr/local/lib/python3.9/dist-packages/imblearn/over_sampling/_smote/base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Train set
# Random Forests roc-auc: 0.958279397611338
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.88      0.87      0.87      2486
#            1       0.87      0.88      0.88      2486
#
#     accuracy                           0.88      4972
#    macro avg       0.88      0.88      0.88      4972
# weighted avg       0.88      0.88      0.88      4972
#
# Test set
# Random Forests roc-auc: 0.9439896596294699
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.86      0.92      1055
#            1       0.30      0.83      0.44        77
#
#     accuracy                           0.86      1132
#    macro avg       0.64      0.84      0.68      1132
# weighted avg       0.94      0.86      0.88      1132
#
#
# balancedRF
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# Train set
# ensembleBoost roc-auc: 0.9772152626134928
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.94      0.97      2486
#            1       0.51      0.94      0.67       154
#
#     accuracy                           0.94      2640
#    macro avg       0.76      0.94      0.82      2640
# weighted avg       0.97      0.94      0.95      2640
#
# Test set
# ensembleBoost roc-auc: 0.9607004370037546
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.92      0.96      1055
#            1       0.46      0.90      0.61        77
#
#     accuracy                           0.92      1132
#    macro avg       0.73      0.91      0.78      1132
# weighted avg       0.96      0.92      0.93      1132
#
#
# bagging
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Train set
# ensembleBoost roc-auc: 0.9350884433346219
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.95      1.00      0.97      2486
#            1       0.67      0.08      0.14       154
#
#     accuracy                           0.94      2640
#    macro avg       0.81      0.54      0.56      2640
# weighted avg       0.93      0.94      0.92      2640
#
# Test set
# ensembleBoost roc-auc: 0.9115405921093125
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97      1055
#            1       0.64      0.09      0.16        77
#
#     accuracy                           0.93      1132
#    macro avg       0.79      0.54      0.56      1132
# weighted avg       0.92      0.93      0.91      1132
#
#
# balancedbagging
# /usr/local/lib/python3.9/dist-packages/imblearn/ensemble/_bagging.py:353: FutureWarning: `base_estimator` was renamed to `estimator` in version 0.10 and will be removed in 0.12.
#   warnings.warn(
# Train set
# ensembleBoost roc-auc: 0.9111178443439103
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.78      0.87      2486
#            1       0.19      0.85      0.31       154
#
#     accuracy                           0.78      2640
#    macro avg       0.59      0.81      0.59      2640
# weighted avg       0.94      0.78      0.84      2640
#
# Test set
# ensembleBoost roc-auc: 0.8966086046654766
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.77      0.86      1055
#            1       0.21      0.87      0.34        77
#
#     accuracy                           0.77      1132
#    macro avg       0.60      0.82      0.60      1132
# weighted avg       0.94      0.77      0.83      1132
#
#
# easyEnsemble
# Train set
# ensembleBoost roc-auc: 0.9879089132910532
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.95      0.97      2486
#            1       0.55      1.00      0.71       154
#
#     accuracy                           0.95      2640
#    macro avg       0.77      0.97      0.84      2640
# weighted avg       0.97      0.95      0.96      2640
#
# Test set
# ensembleBoost roc-auc: 0.9626269465132024
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       1.00      0.93      0.96      1055
#            1       0.51      0.95      0.67        77
#
#     accuracy                           0.94      1132
#    macro avg       0.76      0.94      0.82      1132
# weighted avg       0.96      0.94      0.94      1132
#
#
# arrhythmia
# Train set
# Random Forests roc-auc: 0.9704898681880779
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.95      1.00      0.97       299
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.95       316
#    macro avg       0.47      0.50      0.49       316
# weighted avg       0.90      0.95      0.92       316
#
# Test set
# Random Forests roc-auc: 0.62255859375
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97       128
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.94       136
#    macro avg       0.47      0.50      0.48       136
# weighted avg       0.89      0.94      0.91       136
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Train set
# AdaBoost roc-auc: 1.0
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00       299
#            1       1.00      1.00      1.00        17
#
#     accuracy                           1.00       316
#    macro avg       1.00      1.00      1.00       316
# weighted avg       1.00      1.00      1.00       316
#
# Test set
# AdaBoost roc-auc: 0.9775390625
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.98      0.98      0.98       128
#            1       0.75      0.75      0.75         8
#
#     accuracy                           0.97       136
#    macro avg       0.87      0.87      0.87       136
# weighted avg       0.97      0.97      0.97       136
#
#
# random
# Train set
# Random Forests roc-auc: 1.0
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        17
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
# Test set
# Random Forests roc-auc: 0.8857421875
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.46      0.63       128
#            1       0.10      1.00      0.19         8
#
#     accuracy                           0.49       136
#    macro avg       0.55      0.73      0.41       136
# weighted avg       0.95      0.49      0.60       136
#
#
# smote
# /usr/local/lib/python3.9/dist-packages/imblearn/over_sampling/_smote/base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Train set
# Random Forests roc-auc: 0.9949664992561604
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.93      0.96       299
#            1       0.94      0.99      0.96       299
#
#     accuracy                           0.96       598
#    macro avg       0.96      0.96      0.96       598
# weighted avg       0.96      0.96      0.96       598
#
# Test set
# Random Forests roc-auc: 0.876953125
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.97      0.90      0.93       128
#            1       0.28      0.62      0.38         8
#
#     accuracy                           0.88       136
#    macro avg       0.63      0.76      0.66       136
# weighted avg       0.93      0.88      0.90       136
#
#
# balancedRF
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# Train set
# ensembleBoost roc-auc: 0.9866220735785953
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.66      0.79       299
#            1       0.14      1.00      0.25        17
#
#     accuracy                           0.68       316
#    macro avg       0.57      0.83      0.52       316
# weighted avg       0.95      0.68      0.77       316
#
# Test set
# ensembleBoost roc-auc: 0.8037109375
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.53      0.69       128
#            1       0.10      0.88      0.19         8
#
#     accuracy                           0.55       136
#    macro avg       0.54      0.70      0.44       136
# weighted avg       0.93      0.55      0.66       136
#
#
# bagging
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Train set
# ensembleBoost roc-auc: 0.984457997245721
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.95      1.00      0.97       299
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.95       316
#    macro avg       0.47      0.50      0.49       316
# weighted avg       0.90      0.95      0.92       316
#
# Test set
# ensembleBoost roc-auc: 0.88671875
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/imblearn/ensemble/_bagging.py:353: FutureWarning: `base_estimator` was renamed to `estimator` in version 0.10 and will be removed in 0.12.
#   warnings.warn(
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.97       128
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.94       136
#    macro avg       0.47      0.50      0.48       136
# weighted avg       0.89      0.94      0.91       136
#
#
# balancedbagging
# Train set
# ensembleBoost roc-auc: 0.943537281133189
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.74      0.85       299
#            1       0.18      1.00      0.30        17
#
#     accuracy                           0.75       316
#    macro avg       0.59      0.87      0.58       316
# weighted avg       0.96      0.75      0.82       316
#
# Test set
# ensembleBoost roc-auc: 0.8271484375
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.74      0.85       128
#            1       0.17      0.88      0.29         8
#
#     accuracy                           0.75       136
#    macro avg       0.58      0.81      0.57       136
# weighted avg       0.94      0.75      0.82       136
#
#
# easyEnsemble
# Train set
# ensembleBoost roc-auc: 1.0
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.94      0.97       299
#            1       0.47      1.00      0.64        17
#
#     accuracy                           0.94       316
#    macro avg       0.74      0.97      0.80       316
# weighted avg       0.97      0.94      0.95       316
#
# Test set
# ensembleBoost roc-auc: 0.9990234375
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       1.00      0.90      0.95       128
#            1       0.38      1.00      0.55         8
#
#     accuracy                           0.90       136
#    macro avg       0.69      0.95      0.75       136
# weighted avg       0.96      0.90      0.92       136
#
#
# ozone_level
# Train set
# Random Forests roc-auc: 0.9231215679271396
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99      1723
#            1       0.00      0.00      0.00        52
#
#     accuracy                           0.97      1775
#    macro avg       0.49      0.50      0.49      1775
# weighted avg       0.94      0.97      0.96      1775
#
# Test set
# Random Forests roc-auc: 0.8408622908622909
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99       740
#            1       0.00      0.00      0.00        21
#
#     accuracy                           0.97       761
#    macro avg       0.49      0.50      0.49       761
# weighted avg       0.95      0.97      0.96       761
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Train set
# AdaBoost roc-auc: 0.9904292602348319
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.99      0.99      1723
#            1       0.76      0.62      0.68        52
#
#     accuracy                           0.98      1775
#    macro avg       0.88      0.80      0.84      1775
# weighted avg       0.98      0.98      0.98      1775
#
# Test set
# AdaBoost roc-auc: 0.8387065637065637
# AdaBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.98      0.99      0.98       740
#            1       0.23      0.14      0.18        21
#
#     accuracy                           0.96       761
#    macro avg       0.60      0.56      0.58       761
# weighted avg       0.96      0.96      0.96       761
#
#
# random
# Train set
# Random Forests roc-auc: 0.9534023668639053
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.86      0.85      0.85        52
#            1       0.85      0.87      0.86        52
#
#     accuracy                           0.86       104
#    macro avg       0.86      0.86      0.86       104
# weighted avg       0.86      0.86      0.86       104
#
# Test set
# Random Forests roc-auc: 0.8100707850707851
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.76      0.86       740
#            1       0.08      0.76      0.15        21
#
#     accuracy                           0.76       761
#    macro avg       0.54      0.76      0.50       761
# weighted avg       0.97      0.76      0.84       761
#
#
# smote
# /usr/local/lib/python3.9/dist-packages/imblearn/over_sampling/_smote/base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Train set
# Random Forests roc-auc: 0.95301945714816
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.91      0.84      0.87      1723
#            1       0.85      0.92      0.88      1723
#
#     accuracy                           0.88      3446
#    macro avg       0.88      0.88      0.88      3446
# weighted avg       0.88      0.88      0.88      3446
#
# Test set
# Random Forests roc-auc: 0.8222329472329473
# Random Forests metrics:                precision    recall  f1-score   support
#
#           -1       0.99      0.82      0.90       740
#            1       0.11      0.76      0.19        21
#
#     accuracy                           0.82       761
#    macro avg       0.55      0.79      0.54       761
# weighted avg       0.97      0.82      0.88       761
#
#
# balancedRF
# Train set
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ensembleBoost roc-auc: 0.9607460154471181
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.83      0.91      1723
#            1       0.14      0.94      0.25        52
#
#     accuracy                           0.83      1775
#    macro avg       0.57      0.89      0.58      1775
# weighted avg       0.97      0.83      0.89      1775
#
# Test set
# ensembleBoost roc-auc: 0.8409266409266409
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.81      0.89       740
#            1       0.09      0.67      0.16        21
#
#     accuracy                           0.81       761
#    macro avg       0.54      0.74      0.53       761
# weighted avg       0.96      0.81      0.87       761
#
#
# bagging
# Train set
# ensembleBoost roc-auc: 0.9556899861600965
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99      1723
#            1       1.00      0.06      0.11        52
#
#     accuracy                           0.97      1775
#    macro avg       0.99      0.53      0.55      1775
# weighted avg       0.97      0.97      0.96      1775
#
# Test set
# ensembleBoost roc-auc: 0.8659588159588159
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.97      1.00      0.99       740
#            1       1.00      0.05      0.09        21
#
#     accuracy                           0.97       761
#    macro avg       0.99      0.52      0.54       761
# weighted avg       0.97      0.97      0.96       761
#
#
# balancedbagging
# Train set
# /usr/local/lib/python3.9/dist-packages/imblearn/ensemble/_bagging.py:353: FutureWarning: `base_estimator` was renamed to `estimator` in version 0.10 and will be removed in 0.12.
#   warnings.warn(
# ensembleBoost roc-auc: 0.9364815393544355
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.81      0.89      1723
#            1       0.12      0.87      0.21        52
#
#     accuracy                           0.81      1775
#    macro avg       0.56      0.84      0.55      1775
# weighted avg       0.97      0.81      0.87      1775
#
# Test set
# ensembleBoost roc-auc: 0.8472329472329472
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.79      0.88       740
#            1       0.10      0.76      0.17        21
#
#     accuracy                           0.79       761
#    macro avg       0.54      0.78      0.53       761
# weighted avg       0.97      0.79      0.86       761
#
#
# easyEnsemble
# Train set
# ensembleBoost roc-auc: 0.9904906469038797
# ensembleBoost metrics:                precision    recall  f1-score   support
#
#           -1       1.00      0.82      0.90      1723
#            1       0.15      1.00      0.26        52
#
#     accuracy                           0.83      1775
#    macro avg       0.57      0.91      0.58      1775
# weighted avg       0.97      0.83      0.88      1775
#
# Test set
# ensembleBoost roc-auc: 0.8588159588159588
# ensembleBoost metrics:               precision    recall  f1-score   support
#
#           -1       0.99      0.81      0.89       740
#            1       0.10      0.71      0.17        21
#
#     accuracy                           0.81       761
#    macro avg       0.54      0.76      0.53       761
# weighted avg       0.97      0.81      0.87       761

# %%
for dataset in datasets_ls:
    
    pd.Series(results_dict[dataset]).plot.bar()
    plt.title(dataset)
    plt.ylabel('roc-auc')
    plt.axhline(results_dict[dataset]['full_data'], color='r')
    plt.show()

# %%
for dataset in datasets_ls:
    
    pd.Series(results_dict[dataset]).plot.bar()
    plt.title(dataset)
    plt.ylabel('roc-auc')
    plt.ylim(0.8, 1)
    plt.axhline(results_dict[dataset]['full_data'], color='r')
    plt.show()

# %% [markdown]
# We see that boosting algorithms tend to outperform bagging algorithms. And adding resampling to bagging improves performance, in general, quite a bit.
#
# Note that here, I am comparing the vanilla models for each ensemble. If we put some time into optimising the parameters, surely, we could get better models for each one of these implementations. I leave that as a homework to you.
