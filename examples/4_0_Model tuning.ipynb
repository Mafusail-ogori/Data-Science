# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Read the dataset for churn

# %%
ds = pd.read_csv("/content/drive/MyDrive/НУЛП АСУ /смарт-системи/Інформаційні технології Смарт систем/практичні  роботи/example/data/train.csv")

# %% [markdown]
# ## Data engineering

# %% [markdown]
# #### Missing data imputation

# %%
mean_impute_columns = ['MonthlyRevenue',
 'MonthlyMinutes',
 'TotalRecurringCharge',
 'DirectorAssistedCalls',
 'OverageMinutes',
 'RoamingCalls',
 'PercChangeMinutes',
 'PercChangeRevenues']
mode_impute_columns = [
 'ServiceArea',
 'Handsets',
 'HandsetModels',
 'CurrentEquipmentDays',
 'AgeHH1',
 'AgeHH2']

# %%
def impute_na(df, variable, value):

    return df[variable].fillna(value)

# %%
# Let's create a dict of mean values

mean_impute_values = dict()
for column in mean_impute_columns:
    mean_impute_values[column] = ds[column].mean()
print(mean_impute_values)
# Out:
# {'MonthlyRevenue': 58.834492346387385, 'MonthlyMinutes': 525.6534161246586, 'TotalRecurringCharge': 46.830087834784145, 'DirectorAssistedCalls': 0.895229018883496, 'OverageMinutes': 40.02778487355328, 'RoamingCalls': 1.2362441296103437, 'PercChangeMinutes': -11.547908445146014, 'PercChangeRevenues': -1.19198500394633}

# %%
for column in mean_impute_columns:
    ds[column] = impute_na(ds, column, mean_impute_values[column])

# %%
# Let's create a dict of mode values

mode_impute_values = dict()
for column in mode_impute_columns:
    mode_impute_values[column] = ds[column].mode()[0]
print(mode_impute_values)
# Out:
# {'ServiceArea': 'NYCBRO917', 'Handsets': 1.0, 'HandsetModels': 1.0, 'CurrentEquipmentDays': 202.0, 'AgeHH1': 0.0, 'AgeHH2': 0.0}

# %%
for column in mode_impute_columns:
    ds[column] = impute_na(ds, column, mode_impute_values[column])

# %% [markdown]
# ##### Outlier Engineering

# %%
outlier_columns = ['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge', 
                   'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls', 
                   'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls', 
                   'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 
                   'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 
                   'InboundCalls', 'PeakCallsInOut', 'OffPeakCallsInOut', 
                   'DroppedBlockedCalls', 'CallForwardingCalls', 'CallWaitingCalls', 
                   'MonthsInService', 'UniqueSubs', 'ActiveSubs']

# %%
ds = ds[(np.abs(stats.zscore(ds[outlier_columns])) < 4).all(axis=1)]

# %% [markdown]
# ##### Categorical encoding

# %%
cat_columns = ['Churn',
 'ChildrenInHH',
 'HandsetRefurbished',
 'HandsetWebCapable',
 'TruckOwner',
 'RVOwner',
 'Homeownership',
 'BuysViaMailOrder',
 'RespondsToMailOffers',
 'OptOutMailings',
 'NonUSTravel',
 'OwnsComputer',
 'HasCreditCard',
 'NewCellphoneUser',
 'NotNewCellphoneUser',
 'OwnsMotorcycle',
 'MadeCallToRetentionTeam',
 'MaritalStatus',
 'ServiceArea', 'HandsetPrice','CreditRating', 'PrizmCode', 'Occupation',]

# %%
map_dicts = dict()
for column in cat_columns:
    ds[column] = ds[column].astype('category')
    map_dicts[column] = dict(zip(ds[column], ds[column].cat.codes))
    ds[column] = ds[column].cat.codes

# %%
display(ds.sample(15))
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 3865      3030166      0          103.84           555.0
# 28842     3229070      1           21.83           676.0
# 33719     3268662      1           49.99           168.0
# 17092     3133834      0           40.32           344.0
# 3802      3029742      1           26.76           310.0
# 33550     3267330      1           91.47          1880.0
# 9932      3078314      0           42.55           855.0
# 2958      3023046      0           63.45           585.0
# 26422     3208790      1           56.59           437.0
# 38084     3303602      0           70.96           352.0
# 18657     3146102      0           32.49            90.0
# 7282      3057086      0           37.93           647.0
# 31606     3251822      0           33.85           394.0
# 32361     3257698      0           30.24           206.0
# 4538      3035574      0           55.13           366.0
#
#        TotalRecurringCharge  DirectorAssistedCalls  OverageMinutes  \
# 3865                   85.0                   0.00            52.0
# 28842                  20.0                   2.23            61.0
# 33719                  50.0                   0.00             0.0
# 17092                  30.0                   0.50            26.0
# 3802                   34.0                   0.00            36.0
# 33550                  62.0                   8.66            64.0
# 9932                   42.0                   0.50             9.0
# 2958                   60.0                   3.46             0.0
# 26422                  50.0                   0.00            22.0
# 38084                  55.0                   0.25            74.0
# 18657                  32.0                   0.00             0.0
# 7282                   45.0                   0.25             0.0
# 31606                  40.0                   0.00            11.0
# 32361                  40.0                   0.25             0.0
# 4538                   50.0                   0.74             0.0
#
#        RoamingCalls  PercChangeMinutes  PercChangeRevenues  DroppedCalls  \
# 3865            5.9             -136.0               -20.2           6.3
# 28842           0.5             -674.0               -11.8          10.7
# 33719           0.0              -41.0                 0.0           3.7
# 17092           0.0              -30.0                -9.3           7.0
# 3802            1.4              -16.0               -14.6           1.3
# 33550           0.0             -574.0                60.0          40.3
# 9932            0.0               -1.0                 4.2           1.7
# 2958            0.0              -85.0                 3.5           1.7
# 26422           0.0              -37.0                -6.6           3.0
# 38084           0.0             -244.0               -26.0          38.3
# 18657           0.0                6.0                 0.0           0.0
# 7282            2.7               88.0                -2.9           5.3
# 31606           0.0               50.0                -3.9           3.3
# 32361           0.0              100.0                -0.2           1.3
# 4538            0.0             -145.0                 4.4           3.3
#
#        BlockedCalls  UnansweredCalls  CustomerCareCalls  ThreewayCalls  \
# 3865            0.0             45.3                0.3            0.0
# 28842           0.7             86.0                3.3            0.0
# 33719           3.7             10.0                0.0            0.0
# 17092           0.7             16.3                2.3            0.7
# 3802            7.3              6.0                7.7            0.0
# 33550           6.3             77.0                8.3            3.0
# 9932            8.0             48.7                5.0            0.0
# 2958            5.7             45.7                0.0            0.3
# 26422           3.3             12.7                0.0            0.0
# 38084           7.3             11.7                2.7            0.0
# 18657           0.0              4.7                0.3            0.0
# 7282            1.3             30.0                4.0            0.0
# 31606           0.7             30.7                0.0            0.0
# 32361           2.3              5.0                0.0            0.7
# 4538            5.7             11.3                1.3            0.0
#
#        ReceivedCalls  OutboundCalls  InboundCalls  PeakCallsInOut  \
# 3865           158.7           33.7          25.0           136.0
# 28842          273.0          163.3          70.3           407.0
# 33719           20.6            5.3           0.3            34.3
# 17092           50.3            7.0           0.3            75.3
# 3802            81.8            1.3           0.3           105.0
# 33550          704.1           75.7          26.0           187.0
# 9932           154.1           26.0           0.7           151.7
# 2958           128.8           12.7           0.3           122.7
# 26422          111.0           20.0           5.3            78.3
# 38084           54.8           43.7           4.0            59.7
# 18657           13.7           10.0           1.3            14.3
# 7282             4.8           13.3           0.3            51.7
# 31606          110.2            9.3           6.3            89.3
# 32361           12.8            9.0           0.0            31.3
# 4538           116.0           62.0           3.0           114.7
#
#        OffPeakCallsInOut  DroppedBlockedCalls  CallForwardingCalls  \
# 3865               109.7                  6.3                  0.0
# 28842              112.7                 11.3                  0.0
# 33719               13.3                  7.3                  0.0
# 17092               20.7                  7.7                  0.0
# 3802                20.3                  8.7                  0.0
# 33550              271.3                 46.7                  0.0
# 9932                80.7                  9.7                  0.0
# 2958               123.7                  7.3                  0.0
# 26422               54.0                  6.3                  0.0
# 38084               28.0                 45.7                  0.0
# 18657               15.0                  0.0                  0.0
# 7282                40.7                  6.7                  0.0
# 31606               53.7                  4.0                  0.0
# 32361               11.7                  3.7                  0.0
# 4538               102.0                  9.0                  0.0
#
#        CallWaitingCalls  MonthsInService  UniqueSubs  ActiveSubs  ServiceArea  \
# 3865                2.0               33           2           2          149
# 28842               3.0               17           3           2          597
# 33719               0.7               13           1           1          140
# 17092               0.0               18           1           1           35
# 3802                0.0               37           2           2          320
# 33550              14.3               13           1           1          348
# 9932                0.7               29           1           1          325
# 2958                5.3               36           2           1          128
# 26422               2.7               16           1           1           57
# 38084               1.0               14           1           1          679
# 18657               0.0               21           2           2          656
# 7282                0.3               31           1           1          163
# 31606               0.0               16           1           1          141
# 32361               0.0               12           1           1          383
# 4538                3.0               36           1           1          354
#
#        Handsets  HandsetModels  CurrentEquipmentDays  AgeHH1  AgeHH2  \
# 3865        6.0            5.0                 100.0    34.0    32.0
# 28842       2.0            2.0                 496.0    34.0    34.0
# 33719       2.0            2.0                 128.0     0.0     0.0
# 17092       1.0            1.0                 557.0     0.0     0.0
# 3802        1.0            1.0                1102.0    36.0    36.0
# 33550       1.0            1.0                 388.0    32.0     0.0
# 9932        2.0            2.0                 748.0    42.0     0.0
# 2958        4.0            4.0                 187.0    56.0    34.0
# 26422       1.0            1.0                 481.0    28.0     0.0
# 38084       1.0            1.0                 395.0    78.0     0.0
# 18657       1.0            1.0                 632.0     0.0     0.0
# 7282        1.0            1.0                 930.0    36.0    34.0
# 31606       2.0            2.0                 396.0    62.0    62.0
# 32361       1.0            1.0                 357.0    38.0    34.0
# 4538        7.0            5.0                 669.0    50.0    48.0
#
#        ChildrenInHH  HandsetRefurbished  HandsetWebCapable  TruckOwner  \
# 3865              0                   1                  1           1
# 28842             1                   0                  1           0
# 33719             1                   0                  1           1
# 17092             0                   0                  1           0
# 3802              1                   0                  0           1
# 33550             0                   0                  1           0
# 9932              0                   0                  1           0
# 2958              1                   0                  1           1
# 26422             0                   0                  1           0
# 38084             0                   0                  1           0
# 18657             0                   0                  1           0
# 7282              0                   0                  0           1
# 31606             0                   1                  1           0
# 32361             1                   0                  1           0
# 4538              0                   0                  1           1
#
#        RVOwner  Homeownership  BuysViaMailOrder  RespondsToMailOffers  \
# 3865         1              0                 1                     1
# 28842        0              0                 1                     1
# 33719        1              0                 0                     0
# 17092        0              1                 0                     0
# 3802         0              0                 1                     1
# 33550        0              1                 0                     0
# 9932         0              0                 1                     1
# 2958         0              0                 1                     1
# 26422        0              0                 0                     0
# 38084        0              0                 1                     1
# 18657        0              1                 0                     0
# 7282         0              0                 1                     1
# 31606        0              0                 0                     0
# 32361        0              0                 1                     1
# 4538         0              0                 1                     1
#
#        OptOutMailings  NonUSTravel  OwnsComputer  HasCreditCard  \
# 3865                0            0             1              1
# 28842               0            0             0              1
# 33719               0            0             0              1
# 17092               0            0             0              1
# 3802                0            0             1              1
# 33550               0            0             0              0
# 9932                0            0             0              1
# 2958                0            0             0              1
# 26422               0            0             0              1
# 38084               0            0             0              1
# 18657               0            0             0              0
# 7282                0            0             1              1
# 31606               0            0             0              1
# 32361               0            1             1              1
# 4538                0            0             1              1
#
#        RetentionCalls  RetentionOffersAccepted  NewCellphoneUser  \
# 3865                0                        0                 0
# 28842               0                        0                 0
# 33719               0                        0                 0
# 17092               0                        0                 1
# 3802                0                        0                 0
# 33550               0                        0                 0
# 9932                0                        0                 0
# 2958                0                        0                 1
# 26422               0                        0                 0
# 38084               0                        0                 0
# 18657               0                        0                 0
# 7282                0                        0                 0
# 31606               0                        0                 0
# 32361               0                        0                 0
# 4538                0                        0                 0
#
#        NotNewCellphoneUser  ReferralsMadeBySubscriber  IncomeGroup  \
# 3865                     1                          0            6
# 28842                    0                          0            6
# 33719                    0                          0            9
# 17092                    0                          0            6
# 3802                     1                          0            7
# 33550                    0                          0            0
# 9932                     0                          0            6
# 2958                     0                          0            6
# 26422                    0                          0            6
# 38084                    0                          0            4
# 18657                    0                          0            0
# 7282                     1                          0            6
# 31606                    0                          0            3
# 32361                    0                          0            7
# 4538                     1                          0            6
#
#        OwnsMotorcycle  AdjustmentsToCreditRating  HandsetPrice  \
# 3865                0                          0             3
# 28842               0                          0             8
# 33719               0                          0             2
# 17092               0                          0            15
# 3802                0                          0            15
# 33550               0                          0            15
# 9932                0                          0             8
# 2958                0                          1            13
# 26422               0                          0            15
# 38084               0                          0            15
# 18657               0                          0            15
# 7282                0                          0            15
# 31606               0                          0             3
# 32361               0                          0            15
# 4538                0                          0            14
#
#        MadeCallToRetentionTeam  CreditRating  PrizmCode  Occupation  \
# 3865                         0             0          0           3
# 28842                        0             0          1           4
# 33719                        0             1          3           4
# 17092                        0             6          2           3
# 3802                         0             0          3           4
# 33550                        0             3          2           3
# 9932                         0             1          0           3
# 2958                         0             2          2           3
# 26422                        0             1          2           3
# 38084                        0             6          0           4
# 18657                        0             2          0           3
# 7282                         0             0          3           4
# 31606                        0             1          0           3
# 32361                        0             1          3           4
# 4538                         0             0          2           3
#
#        MaritalStatus
# 3865               2
# 28842              2
# 33719              1
# 17092              1
# 3802               2
# 33550              1
# 9932               0
# 2958               1
# 26422              2
# 38084              0
# 18657              1
# 7282               2
# 31606              0
# 32361              2
# 4538               0

# %% [markdown]
# # Model tuning

# %% [markdown]
# https://en.wikipedia.org/wiki/Hyperparameter_optimization

# %% [markdown]
# #### Parameters vs Hyperparameters
# Let’s now define what are hyperparameters, but before doing that let’s consider the difference between a parameter and a hyperparameter.
#
# A parameter can be considered to be intrinsic or internal to the model and can be obtained after the model has learned from the data.
# Examples of parameters are regression coefficients in linear regression, support vectors in support vector machines and weights in neural networks.
#
# A hyperparameter can be considered to be extrinsic or external to the model and can be set arbitrarily by the practitioner.
# Examples of hyperparameters include the k in k-nearest neighbors, number of trees and maximum number of features in random forest, learning rate and momentum in neural networks, the C and gamma parameters in support vector machines.

# %% [markdown]
# #### Hyperparameter tuning
# As there are no universal best hyperparameters to use for any given problem, hyperparameters are typically set to default values. However, the optimal set of hyperparameters can be obtained from manual empirical (trial-and-error) hyperparameter search or in an automated fashion via the use of optimization algorithm to maximize the fitness function.
#
# Two common hyperparameter tuning methods include grid search and random search. As the name implies, a grid search entails the creation of a grid of possible hyperparameter values whereby models are iteratively built for all of these hyperparameter combinations in a brute force manner. In a random search, not all hyperparameter combinations are used, but instead each iteration makes use of a random hyperparameter combination.

# %% [markdown]
# #### Define target and features columns

# %%
y_column = ['Churn'] # target variable
X_columns = ['MonthlyRevenue', 'MonthlyMinutes',
       'TotalRecurringCharge', 'DirectorAssistedCalls', 'OverageMinutes',
       'RoamingCalls', 'PercChangeMinutes', 'PercChangeRevenues',
       'DroppedCalls', 'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls',
       'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls',
       'PeakCallsInOut', 'OffPeakCallsInOut', 'DroppedBlockedCalls',
       'CallForwardingCalls', 'CallWaitingCalls', 'MonthsInService',
       'UniqueSubs', 'ActiveSubs', 'ServiceArea', 'Handsets', 'HandsetModels',
       'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2', 'ChildrenInHH',
       'HandsetRefurbished', 'HandsetWebCapable', 'TruckOwner', 'RVOwner',
       'Homeownership', 'BuysViaMailOrder', 'RespondsToMailOffers',
       'OptOutMailings', 'NonUSTravel', 'OwnsComputer', 'HasCreditCard',
       'RetentionCalls', 'RetentionOffersAccepted', 'NewCellphoneUser',
       'NotNewCellphoneUser', 'ReferralsMadeBySubscriber', 'IncomeGroup',
       'OwnsMotorcycle', 'AdjustmentsToCreditRating', 'HandsetPrice',
       'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
       'MaritalStatus']
X = ds[X_columns]
y = ds[y_column]

# %%
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
# In the first step we will split the data in training and remaining dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (37354, 56)
# (37354, 1)
# (9339, 56)
# (9339, 1)

# %% [markdown]
# #### Building a Baseline Random Forest Model
# Here, we will first start by building a baseline random forest model that will serve as a baseline for comparative purpose with the model using the optimal set of hyperparameters.
# For the baseline model, we will set an arbitrary number for the 2 hyperparameters (e.g. n_estimators and max_features) that we will also use in the next section for hyperparameter tuning.

# %%
rf = RandomForestClassifier(max_features=5, n_estimators=100)

# %%
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print('test set metrics: ', metrics.classification_report(y_test, y_pred))
# Out:
# test set metrics:                precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83      6633
#            1       0.60      0.07      0.12      2706
#
#     accuracy                           0.72      9339
#    macro avg       0.66      0.52      0.48      9339
# weighted avg       0.69      0.72      0.63      9339

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 5,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #### Hyperparameter Tuning
# Now we will be performing the tuning of hyperparameters of the random forest model.

# %% [markdown]
# n_estimators = number of trees in the foreset
#
# max_features = max number of features considered for splitting a node
#
# max_depth = max number of levels in each decision tree
#
# min_samples_split = min number of data points placed in a node before the node is split
#
# min_samples_leaf = min number of data points allowed in a leaf node
#
# bootstrap = method for sampling data points (with or without replacement)

# %% [markdown]
# https://towardsdatascience.com/hyperparameter-tuning-always-tune-your-models-7db7aeaf47e9

# %%
# %%time
# Create the random grid
param_grid = {'n_estimators': np.arange(25,55,10),
               'max_features': [0.5, 0.6, 0.8],
               'min_samples_split': [10,15],
               'min_samples_leaf': [3,4],
               'bootstrap': [False]}

# print(random_grid)


rf = RandomForestClassifier()

grid = GridSearchCV(estimator=rf, 
                    param_grid=param_grid, 
                    scoring='precision', 
                    cv=5,
                    verbose = 3,
                    return_train_score=True)

grid.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.497) total time=  11.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.511) total time=  11.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.490) total time=  12.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.503) total time=  11.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.500) total time=  12.1s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.521) total time=  15.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.528) total time=  17.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.474) total time=  16.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.512) total time=  16.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.511) total time=  15.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.523) total time=  21.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.531) total time=  20.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.480) total time=  21.0s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.547) total time=  21.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.534) total time=  21.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.493) total time=  11.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.511) total time=  11.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.478) total time=  11.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.493) total time=  11.9s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.999, test=0.524) total time=  11.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.505) total time=  16.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.499) total time=  17.1s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.480) total time=  16.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.502) total time=  15.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.512) total time=  16.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.527) total time=  20.5s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.530) total time=  21.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.483) total time=  20.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.509) total time=  20.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.531) total time=  20.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.491) total time=  11.0s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.485) total time=  11.7s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.468) total time=  11.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.509) total time=  11.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.538) total time=  11.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.531) total time=  15.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.517) total time=  16.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.481) total time=  15.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.499) total time=  15.9s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.553) total time=  15.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.523) total time=  20.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.519) total time=  20.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.480) total time=  20.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.520) total time=  20.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.548) total time=  19.7s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.530) total time=  11.7s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.999, test=0.531) total time=  11.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.461) total time=  11.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.999, test=0.507) total time=  11.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.531) total time=  11.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.537) total time=  16.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.534) total time=  15.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.479) total time=  15.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.518) total time=  15.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.549) total time=  16.1s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.997, test=0.521) total time=  19.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.559) total time=  20.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.500) total time=  20.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.524) total time=  19.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.557) total time=  20.7s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.487) total time=  13.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.512) total time=  13.9s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.464) total time=  13.5s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.510) total time=  13.8s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.499) total time=  13.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.501) total time=  19.6s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.514) total time=  18.2s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.473) total time=  19.5s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.494) total time=  18.2s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.520) total time=  19.7s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.523) total time=  25.1s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.521) total time=  24.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.491) total time=  23.5s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.488) total time=  24.2s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.513) total time=  24.8s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.999, test=0.489) total time=  13.1s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.513) total time=  13.8s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.999, test=0.457) total time=  13.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.508) total time=  13.8s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.486) total time=  13.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.507) total time=  18.8s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.512) total time=  18.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.999, test=0.461) total time=  18.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.506) total time=  18.8s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.514) total time=  23.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.511) total time=  24.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.525) total time=  24.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.472) total time=  24.2s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.506) total time=  24.4s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.530) total time=  24.6s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.474) total time=  13.7s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.499) total time=  13.1s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.450) total time=  13.5s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.486) total time=  12.9s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.515) total time=  13.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.503) total time=  19.0s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.511) total time=  18.7s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.455) total time=  18.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.526) total time=  18.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.518) total time=  18.8s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.521) total time=  23.8s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.510) total time=  23.8s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.486) total time=  25.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.486) total time=  23.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.515) total time=  23.7s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.997, test=0.501) total time=  13.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.505) total time=  12.9s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.997, test=0.469) total time=  13.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.488) total time=  12.8s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.997, test=0.528) total time=  13.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.515) total time=  18.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.515) total time=  18.5s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.464) total time=  18.0s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.527) total time=  18.4s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.530) total time=  18.5s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.997, test=0.520) total time=  23.8s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.536) total time=  24.0s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.469) total time=  23.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.999, test=0.521) total time=  23.1s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.538) total time=  23.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.459) total time=  18.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=1.000, test=0.446) total time=  17.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.431) total time=  18.0s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.485) total time=  18.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.453) total time=  17.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.445) total time=  24.9s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.456) total time=  24.9s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.446) total time=  25.2s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.477) total time=  25.3s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.482) total time=  24.9s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.460) total time=  32.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.493) total time=  32.0s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.454) total time=  32.5s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.469) total time=  31.7s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.485) total time=  32.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.996, test=0.471) total time=  17.0s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.998, test=0.467) total time=  18.3s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.996, test=0.444) total time=  17.0s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.997, test=0.470) total time=  17.5s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.995, test=0.475) total time=  18.5s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.998, test=0.479) total time=  24.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.473) total time=  24.7s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.444) total time=  24.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.484) total time=  24.8s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.996, test=0.492) total time=  25.3s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.996, test=0.462) total time=  31.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.471) total time=  32.1s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.469) total time=  31.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.483) total time=  32.0s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.996, test=0.484) total time=  31.9s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.467) total time=  17.8s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.999, test=0.440) total time=  17.0s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.434) total time=  17.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.473) total time=  17.9s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.997, test=0.484) total time=  18.2s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.477) total time=  24.8s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.467) total time=  25.0s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.438) total time=  24.3s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.999, test=0.474) total time=  24.2s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.477) total time=  25.1s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.477) total time=  31.5s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.450) total time=  31.9s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.451) total time=  30.9s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.999, test=0.473) total time=  31.2s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.485) total time=  32.0s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.996, test=0.468) total time=  17.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.997, test=0.459) total time=  18.0s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.995, test=0.446) total time=  16.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.996, test=0.484) total time=  17.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.995, test=0.482) total time=  17.3s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.996, test=0.489) total time=  24.2s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.462) total time=  24.1s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.995, test=0.455) total time=  24.0s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.483) total time=  24.1s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.995, test=0.500) total time=  24.0s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.997, test=0.492) total time=  31.5s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.998, test=0.481) total time=  31.2s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.996, test=0.468) total time=  31.0s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.997, test=0.481) total time=  31.1s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.994, test=0.496) total time=  31.2s
# The best parameters are {'bootstrap': False, 'max_features': 0.5, 'min_samples_leaf': 4, 'min_samples_split': 15, 'n_estimators': 45} with a score of 0.53
# CPU times: user 1h 10s, sys: 3.57 s, total: 1h 14s
# Wall time: 1h 37s

# %%
grid_results = pd.concat([pd.DataFrame(grid.cv_results_["params"]),
                          pd.DataFrame(grid.cv_results_["mean_test_score"], 
                          columns=["precision"])],
                          axis=1)

grid_results
# Out:
#     bootstrap  max_features  min_samples_leaf  min_samples_split  \
# 0       False           0.5                 3                 10
# 1       False           0.5                 3                 10
# 2       False           0.5                 3                 10
# 3       False           0.5                 3                 15
# 4       False           0.5                 3                 15
# 5       False           0.5                 3                 15
# 6       False           0.5                 4                 10
# 7       False           0.5                 4                 10
# 8       False           0.5                 4                 10
# 9       False           0.5                 4                 15
# 10      False           0.5                 4                 15
# 11      False           0.5                 4                 15
# 12      False           0.6                 3                 10
# 13      False           0.6                 3                 10
# 14      False           0.6                 3                 10
# 15      False           0.6                 3                 15
# 16      False           0.6                 3                 15
# 17      False           0.6                 3                 15
# 18      False           0.6                 4                 10
# 19      False           0.6                 4                 10
# 20      False           0.6                 4                 10
# 21      False           0.6                 4                 15
# 22      False           0.6                 4                 15
# 23      False           0.6                 4                 15
# 24      False           0.8                 3                 10
# 25      False           0.8                 3                 10
# 26      False           0.8                 3                 10
# 27      False           0.8                 3                 15
# 28      False           0.8                 3                 15
# 29      False           0.8                 3                 15
# 30      False           0.8                 4                 10
# 31      False           0.8                 4                 10
# 32      False           0.8                 4                 10
# 33      False           0.8                 4                 15
# 34      False           0.8                 4                 15
# 35      False           0.8                 4                 15
#
#     n_estimators  precision
# 0             25   0.500409
# 1             35   0.509282
# 2             45   0.523058
# 3             25   0.499740
# 4             35   0.499457
# 5             45   0.516006
# 6             25   0.498440
# 7             35   0.516017
# 8             45   0.517900
# 9             25   0.511928
# 10            35   0.523562
# 11            45   0.532116
# 12            25   0.494649
# 13            35   0.500389
# 14            45   0.507257
# 15            25   0.490491
# 16            35   0.499840
# 17            45   0.508984
# 18            25   0.484700
# 19            35   0.502302
# 20            45   0.503399
# 21            25   0.498156
# 22            35   0.510184
# 23            45   0.516567
# 24            25   0.454833
# 25            35   0.461177
# 26            45   0.472321
# 27            25   0.465636
# 28            35   0.474251
# 29            45   0.473806
# 30            25   0.459600
# 31            35   0.466359
# 32            45   0.467395
# 33            25   0.467635
# 34            35   0.477657
# 35            45   0.483768

# %%
grid_results.columns
# Out:
# Index(['bootstrap', 'max_features', 'min_samples_leaf', 'min_samples_split',
#        'n_estimators', 'precision'],
#       dtype='object')

# %%
grid_contour = grid_results.groupby([  'max_features', 'min_samples_leaf',
       'min_samples_split', 'n_estimators']).mean()
grid_contour
# Out:
#                                                               bootstrap  \
# max_features min_samples_leaf min_samples_split n_estimators
# 0.5          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
# 0.6          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
# 0.8          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#
#                                                               precision
# max_features min_samples_leaf min_samples_split n_estimators
# 0.5          3                10                25             0.500409
#                                                 35             0.509282
#                                                 45             0.523058
#                               15                25             0.499740
#                                                 35             0.499457
#                                                 45             0.516006
#              4                10                25             0.498440
#                                                 35             0.516017
#                                                 45             0.517900
#                               15                25             0.511928
#                                                 35             0.523562
#                                                 45             0.532116
# 0.6          3                10                25             0.494649
#                                                 35             0.500389
#                                                 45             0.507257
#                               15                25             0.490491
#                                                 35             0.499840
#                                                 45             0.508984
#              4                10                25             0.484700
#                                                 35             0.502302
#                                                 45             0.503399
#                               15                25             0.498156
#                                                 35             0.510184
#                                                 45             0.516567
# 0.8          3                10                25             0.454833
#                                                 35             0.461177
#                                                 45             0.472321
#                               15                25             0.465636
#                                                 35             0.474251
#                                                 45             0.473806
#              4                10                25             0.459600
#                                                 35             0.466359
#                                                 45             0.467395
#                               15                25             0.467635
#                                                 35             0.477657
#                                                 45             0.483768
